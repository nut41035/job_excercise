# %%
from django.core.mail import send_mail

# %%
EMAIL_BACKEND = 'django.core.mail.backends.smtp.EmailBackend'
EMAIL_HOST = 'smtp.gmail.com'
EMAIL_PORT = '587'
EMAIL_HOST_USER = 'excercise.sender@gmail.com'
EMAIL_HOST_PASSWORD = 'P@ssw012d'
EMAIL_USE_TLS = True
EMAIL_USE_SSL = False

# %%
send_mail(
    'That’s your subject',
    'That’s your message body',
    'from@yourdjangoapp.com',
    ['to@yourbestuser.com'],
    fail_silently=False,
)
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-10-3a0a1846b111> in <module>
# ----> 1 send_mail(
#       2     'That’s your subject',
#       3     'That’s your message body',
#       4     'from@yourdjangoapp.com',
#       5     ['to@yourbestuser.com'],
#
# ~/.local/lib/python3.8/site-packages/django/core/mail/__init__.py in send_mail(subject, message, from_email, recipient_list, fail_silently, auth_user, auth_password, connection, html_message)
#      50     functionality should use the EmailMessage class directly.
#      51     """
# ---> 52     connection = connection or get_connection(
#      53         username=auth_user,
#      54         password=auth_password,
#
# ~/.local/lib/python3.8/site-packages/django/core/mail/__init__.py in get_connection(backend, fail_silently, **kwds)
#      32     constructor of the backend.
#      33     """
# ---> 34     klass = import_string(backend or settings.EMAIL_BACKEND)
#      35     return klass(fail_silently=fail_silently, **kwds)
#      36
#
# ~/.local/lib/python3.8/site-packages/django/conf/__init__.py in __getattr__(self, name)
#      80         """Return the value of a setting and cache it in self.__dict__."""
#      81         if self._wrapped is empty:
# ---> 82             self._setup(name)
#      83         val = getattr(self._wrapped, name)
#      84         self.__dict__[name] = val
#
# ~/.local/lib/python3.8/site-packages/django/conf/__init__.py in _setup(self, name)
#      61         if not settings_module:
#      62             desc = ("setting %s" % name) if name else "settings"
# ---> 63             raise ImproperlyConfigured(
#      64                 "Requested %s, but settings are not configured. "
#      65                 "You must either define the environment variable %s "
#
# ImproperlyConfigured: Requested setting EMAIL_BACKEND, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
